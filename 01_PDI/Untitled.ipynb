# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
input_img = cv.imread('im_contrast_3.jpg', cv.IMREAD_COLOR)
input_img = cv.cvtColor(input_img, cv.COLOR_BGR2GRAY)
plt.imshow(input_img)
# input_img = cv.cvtColor(input_img, cv.COLOR_RGB2BGR)

#img = input_img[:,:,::-1]

# %%
i_min = np.min(input_img)
i_max = np.max(input_img)

# %% [markdown]
# $$ A = {x | 0 < x < 254 }$$

# %% [markdown]
# $$ B = {y | 0 < y < 255 }$$

# %%
A = 100
B = 150
# rango de la imagen
C = 0
D = 255
plt.imshow(input_img)

# %%
im = input_img

im[input_img < A] = C
im[input_img > B] = C
im[input_img != C] = D
plt.imshow(im)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f870ce2e2d66> in <module>
# ----> 1 im = input_img
#       2
#       3 im[input_img < A] = C
#       4 im[input_img > B] = C
#       5 im[input_img != C] = D
#
# NameError: name 'input_img' is not defined
